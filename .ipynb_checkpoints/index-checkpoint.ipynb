# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge on Join statements.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
conn = sqlite3.Connection('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
cur.execute('''
SELECT  lastname, firstname FROM employees JOIN offices using(officeCode) WHERE offices.city = "Boston"
''').fetchall()
# Out:
# [('Firrelli', 'Julie'), ('Patterson', 'Steve')]

# %%
cur.execute('''
Select * FROM employees LIMIT 20
''').fetchall()
# Out:
# [('1002',
#   'Murphy',
#   'Diane',
#   'x5800',
#   'dmurphy@classicmodelcars.com',
#   '1',
#   '',
#   'President'),
#  ('1056',
#   'Patterson',
#   'Mary',
#   'x4611',
#   'mpatterso@classicmodelcars.com',
#   '1',
#   '1002',
#   'VP Sales'),
#  ('1076',
#   'Firrelli',
#   'Jeff',
#   'x9273',
#   'jfirrelli@classicmodelcars.com',
#   '1',
#   '1002',
#   'VP Marketing'),
#  ('1088',
#   'Patterson',
#   'William',
#   'x4871',
#   'wpatterson@classicmodelcars.com',
#   '6',
#   '1056',
#   'Sales Manager (APAC)'),
#  ('1102',
#   'Bondur',
#   'Gerard',
#   'x5408',
#   'gbondur@classicmodelcars.com',
#   '4',
#   '1056',
#   'Sale Manager (EMEA)'),
#  ('1143',
#   'Bow',
#   'Anthony',
#   'x5428',
#   'abow@classicmodelcars.com',
#   '1',
#   '1056',
#   'Sales Manager (NA)'),
#  ('1165',
#   'Jennings',
#   'Leslie',
#   'x3291',
#   'ljennings@classicmodelcars.com',
#   '1',
#   '1143',
#   'Sales Rep'),
#  ('1166',
#   'Thompson',
#   'Leslie',
#   'x4065',
#   'lthompson@classicmodelcars.com',
#   '1',
#   '1143',
#   'Sales Rep'),
#  ('1188',
#   'Firrelli',
#   'Julie',
#   'x2173',
#   'jfirrelli@classicmodelcars.com',
#   '2',
#   '1143',
#   'Sales Rep'),
#  ('1216',
#   'Patterson',
#   'Steve',
#   'x4334',
#   'spatterson@classicmodelcars.com',
#   '2',
#   '1143',
#   'Sales Rep'),
#  ('1286',
#   'Tseng',
#   'Foon Yue',
#   'x2248',
#   'ftseng@classicmodelcars.com',
#   '3',
#   '1143',
#   'Sales Rep'),
#  ('1323',
#   'Vanauf',
#   'George',
#   'x4102',
#   'gvanauf@classicmodelcars.com',
#   '3',
#   '1143',
#   'Sales Rep'),
#  ('1337',
#   'Bondur',
#   'Loui',
#   'x6493',
#   'lbondur@classicmodelcars.com',
#   '4',
#   '1102',
#   'Sales Rep'),
#  ('1370',
#   'Hernandez',
#   'Gerard',
#   'x2028',
#   'ghernande@classicmodelcars.com',
#   '4',
#   '1102',
#   'Sales Rep'),
#  ('1401',
#   'Castillo',
#   'Pamela',
#   'x2759',
#   'pcastillo@classicmodelcars.com',
#   '4',
#   '1102',
#   'Sales Rep'),
#  ('1501',
#   'Bott',
#   'Larry',
#   'x2311',
#   'lbott@classicmodelcars.com',
#   '7',
#   '1102',
#   'Sales Rep'),
#  ('1504',
#   'Jones',
#   'Barry',
#   'x102',
#   'bjones@classicmodelcars.com',
#   '7',
#   '1102',
#   'Sales Rep'),
#  ('1611',
#   'Fixter',
#   'Andy',
#   'x101',
#   'afixter@classicmodelcars.com',
#   '6',
#   '1088',
#   'Sales Rep'),
#  ('1612',
#   'Marsh',
#   'Peter',
#   'x102',
#   'pmarsh@classicmodelcars.com',
#   '6',
#   '1088',
#   'Sales Rep'),
#  ('1619',
#   'King',
#   'Tom',
#   'x103',
#   'tking@classicmodelcars.com',
#   '6',
#   '1088',
#   'Sales Rep')]

# %%
cur.execute('''
Select * FROM offices WHERE city = "Boston"
''').fetchall()
# Out:
# [('2',
#   'Boston',
#   '+1 215 837 0825',
#   '1550 Court Place',
#   'Suite 102',
#   'MA',
#   'USA',
#   '02107',
#   'NA')]

# %%
cur.execute('''
SELECT * FROM sqlite_master WHERE name = 'employees'
''').fetchall()
# Out:
# [('table',
#   'employees',
#   'employees',
#   56,
#   'CREATE TABLE `employees` (`employeeNumber`, `lastName`, `firstName`, `extension`, `email`, `officeCode`, `reportsTo`, `jobTitle`)')]

# %% [markdown]
# I was trying to find the datatypes of the columns.  I thought they would be seen from the original CREATE TABLE command

# %% [markdown]
# ## Do any offices have no employees?

# %%
cur.execute('''
SELECT DISTINCT officeCode FROM employees
''').fetchall()
# Out:
# [('1',), ('6',), ('4',), ('2',), ('3',), ('7',), ('5',)]

# %%
cur.execute('''
SELECT DISTINCT officeCode FROM offices
''').fetchall()
# Out:
# [('1',), ('2',), ('3',), ('4',), ('5',), ('6',), ('7',)]

# %% [markdown]
# No.  All offices have at least an employee.  Each office code is represented in the employees table

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %% [markdown]
# Which customers made purchases of over 30,000? (Big time clients)
# Edit** Doesn't seem to be working.  Is the number stored as a string for some reason?

# %%
cur.execute('''
Select customerName, paymentDate, amount FROM customers JOIN payments using(customerNumber) WHERE payments.amount > 30000
''').fetchall()
# Out:
# [('Atelier graphique', '2004-10-19', '6066.78'),
#  ('Atelier graphique', '2003-06-05', '14571.44'),
#  ('Atelier graphique', '2004-12-18', '1676.14'),
#  ('Signal Gift Stores', '2004-12-17', '14191.12'),
#  ('Signal Gift Stores', '2003-06-06', '32641.98'),
#  ('Signal Gift Stores', '2004-08-20', '33347.88'),
#  ('Australian Collectors, Co.', '2003-05-20', '45864.03'),
#  ('Australian Collectors, Co.', '2004-12-15', '82261.22'),
#  ('Australian Collectors, Co.', '2003-05-31', '7565.08'),
#  ('Australian Collectors, Co.', '2004-03-10', '44894.74'),
#  ('La Rochelle Gifts', '2004-11-14', '19501.82'),
#  ('La Rochelle Gifts', '2004-08-08', '47924.19'),
#  ('La Rochelle Gifts', '2005-02-22', '49523.67'),
#  ('Baane Mini Imports', '2003-02-16', '50218.95'),
#  ('Baane Mini Imports', '2003-10-28', '1491.38'),
#  ('Baane Mini Imports', '2004-11-04', '17876.32'),
#  ('Baane Mini Imports', '2004-11-28', '34638.14'),
#  ('Mini Gifts Distributors Ltd.', '2005-03-05', '101244.59'),
#  ('Mini Gifts Distributors Ltd.', '2004-08-28', '85410.87'),
#  ('Mini Gifts Distributors Ltd.', '2003-04-11', '11044.30'),
#  ('Mini Gifts Distributors Ltd.', '2005-04-16', '83598.04'),
#  ('Mini Gifts Distributors Ltd.', '2004-12-27', '47142.70'),
#  ('Mini Gifts Distributors Ltd.', '2004-11-02', '55639.66'),
#  ('Mini Gifts Distributors Ltd.', '2003-08-15', '111654.40'),
#  ('Mini Gifts Distributors Ltd.', '2004-03-26', '43369.30'),
#  ('Mini Gifts Distributors Ltd.', '2003-11-25', '45084.38'),
#  ('Blauer See Auto, Co.', '2003-01-28', '10549.01'),
#  ('Blauer See Auto, Co.', '2003-10-18', '24101.81'),
#  ('Blauer See Auto, Co.', '2004-03-24', '33820.62'),
#  ('Blauer See Auto, Co.', '2004-11-18', '7466.32'),
#  ('Mini Wheels Co.', '2004-12-08', '26248.78'),
#  ('Mini Wheels Co.', '2003-12-11', '23923.93'),
#  ('Mini Wheels Co.', '2003-04-09', '16537.85'),
#  ('Land of Toys Inc.', '2003-03-12', '22292.62'),
#  ('Land of Toys Inc.', '2004-12-02', '50025.35'),
#  ('Land of Toys Inc.', '2004-09-11', '35321.97'),
#  ('Euro+ Shopping Channel', '2003-07-19', '36251.03'),
#  ('Euro+ Shopping Channel', '2004-11-01', '36140.38'),
#  ('Euro+ Shopping Channel', '2005-05-19', '46895.48'),
#  ('Euro+ Shopping Channel', '2004-01-30', '59830.55'),
#  ('Euro+ Shopping Channel', '2004-12-31', '116208.40'),
#  ('Euro+ Shopping Channel', '2005-03-25', '65071.26'),
#  ('Euro+ Shopping Channel', '2005-03-18', '120166.58'),
#  ('Euro+ Shopping Channel', '2003-10-26', '49539.37'),
#  ('Euro+ Shopping Channel', '2003-02-25', '40206.20'),
#  ('Euro+ Shopping Channel', '2003-12-09', '63843.55'),
#  ('Euro+ Shopping Channel', '2004-07-09', '35420.74'),
#  ('Euro+ Shopping Channel', '2004-08-16', '20009.53'),
#  ('Euro+ Shopping Channel', '2004-05-17', '26155.91'),
#  ('Volvo Model Replicas, Co', '2004-12-12', '36005.71'),
#  ('Volvo Model Replicas, Co', '2003-04-09', '7674.94'),
#  ('Danish Wholesale Imports', '2004-07-03', '4710.73'),
#  ('Danish Wholesale Imports', '2004-04-26', '28211.70'),
#  ('Danish Wholesale Imports', '2004-12-01', '20564.86'),
#  ('Danish Wholesale Imports', '2003-02-20', '53959.21'),
#  ('Saveley & Henriot, Co.', '2004-03-18', '40978.53'),
#  ('Saveley & Henriot, Co.', '2004-01-16', '49614.72'),
#  ('Saveley & Henriot, Co.', '2003-12-10', '39712.10'),
#  ('Dragon Souveniers, Ltd.', '2003-04-22', '44380.15'),
#  ('Dragon Souveniers, Ltd.', '2004-08-11', '2611.84'),
#  ('Dragon Souveniers, Ltd.', '2003-12-26', '105743.00'),
#  ('Dragon Souveniers, Ltd.', '2005-03-27', '3516.04'),
#  ('Muscle Machine Inc', '2003-12-22', '58793.53'),
#  ('Muscle Machine Inc', '2004-07-26', '20314.44'),
#  ('Muscle Machine Inc', '2003-06-18', '58841.35'),
#  ('Muscle Machine Inc', '2004-12-14', '39964.63'),
#  ('Diecast Classics Inc.', '2004-11-19', '35152.12'),
#  ('Diecast Classics Inc.', '2004-09-07', '63357.13'),
#  ('Technics Stores Inc.', '2004-11-14', '2434.25'),
#  ('Technics Stores Inc.', '2003-11-18', '50743.65'),
#  ('Technics Stores Inc.', '2005-02-02', '12692.19'),
#  ('Technics Stores Inc.', '2003-08-05', '38675.13'),
#  ('Handji Gifts& Co', '2004-09-16', '38785.48'),
#  ('Handji Gifts& Co', '2004-07-07', '44160.92'),
#  ('Handji Gifts& Co', '2004-02-28', '22474.17'),
#  ('Herkku Gifts', '2004-09-19', '12538.01'),
#  ('Herkku Gifts', '2003-12-03', '85024.46'),
#  ('Daedalus Designs Imports', '2004-03-15', '18997.89'),
#  ('Daedalus Designs Imports', '2003-11-22', '42783.81'),
#  ("La Corne D'abondance, Co.", '2004-09-09', '1960.80'),
#  ("La Corne D'abondance, Co.", '2004-12-04', '51209.58'),
#  ("La Corne D'abondance, Co.", '2003-04-20', '33383.14'),
#  ('Cambridge Collectables Co.', '2004-05-13', '11843.45'),
#  ('Cambridge Collectables Co.', '2004-03-29', '20355.24'),
#  ('Gift Depot Inc.', '2005-05-19', '28500.78'),
#  ('Gift Depot Inc.', '2003-11-19', '24879.08'),
#  ('Gift Depot Inc.', '2004-07-10', '42044.77'),
#  ('Osaka Souveniers Co.', '2004-04-17', '15183.63'),
#  ('Osaka Souveniers Co.', '2004-01-19', '47177.59'),
#  ('Vitachrome Inc.', '2004-04-25', '22602.36'),
#  ('Vitachrome Inc.', '2003-01-30', '5494.78'),
#  ('Vitachrome Inc.', '2004-11-16', '44400.50'),
#  ('Toys of Finland, Co.', '2005-03-10', '23602.90'),
#  ('Toys of Finland, Co.', '2003-10-27', '37602.48'),
#  ('Toys of Finland, Co.', '2004-10-21', '34341.08'),
#  ('AV Stores, Co.', '2004-11-03', '52825.29'),
#  ('AV Stores, Co.', '2004-12-08', '47159.11'),
#  ('AV Stores, Co.', '2003-03-27', '48425.69'),
#  ('Clover Collections, Co.', '2004-10-03', '17359.53'),
#  ('Clover Collections, Co.', '2004-03-01', '32538.74'),
#  ('Auto-Moto Classics Inc.', '2004-12-06', '9658.74'),
#  ('Auto-Moto Classics Inc.', '2003-07-06', '6036.96'),
#  ('Auto-Moto Classics Inc.', '2004-09-21', '5858.56'),
#  ('UK Collectables, Ltd.', '2003-10-20', '23908.24'),
#  ('UK Collectables, Ltd.', '2004-06-15', '37258.94'),
#  ('Canadian Gift Exchange Network', '2003-12-18', '36527.61'),
#  ('Canadian Gift Exchange Network', '2004-11-08', '33594.58'),
#  ('Online Mini Collectables', '2004-08-13', '51152.86'),
#  ('Online Mini Collectables', '2004-09-24', '4424.40'),
#  ('Toys4GrownUps.com', '2003-12-04', '3879.96'),
#  ('Toys4GrownUps.com', '2003-09-05', '50342.74'),
#  ('Toys4GrownUps.com', '2005-02-06', '39580.60'),
#  ('Mini Caravy', '2005-05-03', '35157.75'),
#  ('Mini Caravy', '2004-06-21', '4632.31'),
#  ('Mini Caravy', '2004-05-04', '36069.26'),
#  ('King Kong Collectables, Co.', '2003-12-09', '45480.79'),
#  ('Enaco Distributors', '2003-05-09', '3101.40'),
#  ('Enaco Distributors', '2004-12-06', '24945.21'),
#  ('Enaco Distributors', '2003-12-14', '40473.86'),
#  ('Boards & Toys Co.', '2005-03-02', '3452.75'),
#  ('Boards & Toys Co.', '2003-10-18', '4465.85'),
#  ('Heintze Collectables', '2003-10-31', '36164.46'),
#  ('Heintze Collectables', '2004-11-02', '53745.34'),
#  ('Québec Home Shopping Network', '2005-05-20', '29070.38'),
#  ('Québec Home Shopping Network', '2004-07-01', '22997.45'),
#  ('Québec Home Shopping Network', '2003-11-18', '16909.84'),
#  ('Collectable Mini Designs Co.', '2004-03-15', '80375.24'),
#  ('giftsbymail.co.uk', '2004-11-16', '46788.14'),
#  ('giftsbymail.co.uk', '2004-03-28', '24995.61'),
#  ('Alpha Cognac', '2003-11-22', '33818.34'),
#  ('Alpha Cognac', '2005-06-03', '12432.32'),
#  ('Alpha Cognac', '2003-07-21', '14232.70'),
#  ('Amica Models & Co.', '2004-09-19', '33924.24'),
#  ('Amica Models & Co.', '2004-09-04', '48298.99'),
#  ('Lyon Souveniers', '2005-05-17', '17928.09'),
#  ('Lyon Souveniers', '2004-12-30', '26311.63'),
#  ('Lyon Souveniers', '2003-07-18', '23419.47'),
#  ('Auto Associés & Cie.', '2004-02-10', '5759.42'),
#  ('Auto Associés & Cie.', '2004-10-22', '53116.99'),
#  ('Toms Spezialitäten, Ltd', '2004-11-06', '61234.67'),
#  ('Toms Spezialitäten, Ltd', '2003-12-07', '27988.47'),
#  ('Royal Canadian Collectables, Ltd.', '2004-08-30', '37527.58'),
#  ('Royal Canadian Collectables, Ltd.', '2004-04-24', '29284.42'),
#  ("Anna's Decorations, Ltd", '2005-02-09', '27083.78'),
#  ("Anna's Decorations, Ltd", '2003-11-13', '38547.19'),
#  ("Anna's Decorations, Ltd", '2003-09-28', '41554.73'),
#  ("Anna's Decorations, Ltd", '2005-04-30', '29848.52'),
#  ('Rovelli Gifts', '2004-12-05', '37654.09'),
#  ('Rovelli Gifts', '2003-03-02', '52151.81'),
#  ('Rovelli Gifts', '2003-11-24', '37723.79'),
#  ('Souveniers And Things Co.', '2003-08-03', '24013.52'),
#  ('Souveniers And Things Co.', '2004-08-02', '35806.73'),
#  ('Souveniers And Things Co.', '2005-01-03', '31835.36'),
#  ("Marta's Replicas Co.", '2004-10-28', '47411.33'),
#  ("Marta's Replicas Co.", '2004-09-05', '43134.04'),
#  ('Vida Sport, Ltd', '2004-03-13', '47375.92'),
#  ('Vida Sport, Ltd', '2004-09-18', '61402.00'),
#  ('Norway Gifts By Mail, Co.', '2003-10-24', '36798.88'),
#  ('Norway Gifts By Mail, Co.', '2004-09-05', '32260.16'),
#  ('Oulu Toy Supplies, Inc.', '2005-02-15', '46770.52'),
#  ('Oulu Toy Supplies, Inc.', '2003-10-06', '32723.04'),
#  ('Oulu Toy Supplies, Inc.', '2004-04-25', '16212.59'),
#  ('Petit Auto', '2004-08-09', '45352.47'),
#  ('Petit Auto', '2004-03-03', '16901.38'),
#  ('Mini Classics', '2004-11-06', '42339.76'),
#  ('Mini Classics', '2003-12-07', '36092.40'),
#  ('Mini Creations Ltd.', '2005-01-18', '8307.28'),
#  ('Mini Creations Ltd.', '2003-08-20', '41016.75'),
#  ('Mini Creations Ltd.', '2003-11-24', '52548.49'),
#  ('Corporate Gift Ideas Co.', '2003-11-03', '85559.12'),
#  ('Corporate Gift Ideas Co.', '2005-03-15', '46781.66'),
#  ('Down Under Souveniers, Inc', '2005-05-23', '75020.13'),
#  ('Down Under Souveniers, Inc', '2004-06-24', '37281.36'),
#  ('Down Under Souveniers, Inc', '2003-07-05', '2880.00'),
#  ('Down Under Souveniers, Inc', '2004-12-24', '39440.59'),
#  ('Stylish Desk Decors, Co.', '2004-12-13', '13671.82'),
#  ('Stylish Desk Decors, Co.', '2003-07-07', '29429.14'),
#  ('Stylish Desk Decors, Co.', '2003-11-23', '37455.77'),
#  ('Tekni Collectables Inc.', '2004-04-16', '7178.66'),
#  ('Tekni Collectables Inc.', '2004-05-30', '31102.85'),
#  ('Australian Gift Network, Co', '2003-11-15', '23936.53'),
#  ('Australian Gift Network, Co', '2003-10-17', '9821.32'),
#  ('Australian Gift Network, Co', '2005-03-01', '21432.31'),
#  ('Suominen Souveniers', '2005-01-27', '45785.34'),
#  ('Suominen Souveniers', '2003-08-16', '29716.86'),
#  ('Suominen Souveniers', '2004-05-22', '28394.54'),
#  ('Classic Gift Ideas, Inc', '2004-10-24', '23333.06'),
#  ('Classic Gift Ideas, Inc', '2003-11-28', '34606.28'),
#  ('CAF Imports', '2003-11-24', '31428.21'),
#  ('CAF Imports', '2004-04-02', '15322.93'),
#  ("Men 'R' US Retailers, Ltd.", '2004-01-18', '21053.69'),
#  ("Men 'R' US Retailers, Ltd.", '2003-10-24', '20452.50'),
#  ('Marseille Mini Autos', '2004-12-11', '18888.31'),
#  ('Marseille Mini Autos', '2003-05-25', '50824.66'),
#  ('Marseille Mini Autos', '2005-01-29', '1834.56'),
#  ('Reims Collectables', '2005-01-10', '49705.52'),
#  ('Reims Collectables', '2003-07-21', '13920.26'),
#  ('Reims Collectables', '2003-05-21', '16700.47'),
#  ('Reims Collectables', '2005-06-09', '46656.94'),
#  ('GiftsForHim.com', '2003-12-16', '20220.04'),
#  ('GiftsForHim.com', '2004-05-15', '36442.34'),
#  ('Gifts4AllAges.com', '2004-07-11', '18473.71'),
#  ('Gifts4AllAges.com', '2004-09-21', '15059.76'),
#  ('Online Diecast Creations Co.', '2004-11-17', '50799.69'),
#  ('Online Diecast Creations Co.', '2003-01-16', '10223.83'),
#  ('Online Diecast Creations Co.', '2003-12-05', '55425.77'),
#  ('Collectables For Less Inc.', '2005-02-12', '28322.83'),
#  ('Collectables For Less Inc.', '2003-09-16', '32680.31'),
#  ('Collectables For Less Inc.', '2004-08-02', '12530.51'),
#  ('Royale Belge', '2004-12-03', '12081.52'),
#  ('Royale Belge', '2003-04-19', '1627.56'),
#  ('Royale Belge', '2005-02-03', '14379.90'),
#  ('Royale Belge', '2003-08-22', '1128.20'),
#  ('Salzburg Collectables', '2003-05-12', '35826.33'),
#  ('Salzburg Collectables', '2004-08-01', '6419.84'),
#  ('Salzburg Collectables', '2004-11-27', '42813.83'),
#  ('Cruz & Sons Co.', '2003-12-02', '20644.24'),
#  ('Cruz & Sons Co.', '2004-11-19', '15822.84'),
#  ('Cruz & Sons Co.', '2003-03-09', '51001.22'),
#  ("L'ordine Souveniers", '2003-11-18', '38524.29'),
#  ("L'ordine Souveniers", '2004-07-18', '51619.02'),
#  ('Tokyo Collectables, Ltd', '2005-02-14', '33967.73'),
#  ('Tokyo Collectables, Ltd', '2004-06-21', '22037.91'),
#  ('Tokyo Collectables, Ltd', '2005-05-18', '615.45'),
#  ('Tokyo Collectables, Ltd', '2004-11-29', '48927.64'),
#  ('Auto Canal+ Petit', '2005-04-23', '12190.85'),
#  ('Auto Canal+ Petit', '2004-01-28', '49165.16'),
#  ('Auto Canal+ Petit', '2004-06-17', '25080.96'),
#  ('Extreme Desk Decorations, Ltd', '2004-07-25', '35034.57'),
#  ('Extreme Desk Decorations, Ltd', '2004-04-14', '31670.37'),
#  ('Bavarian Collectables Imports, Co.', '2004-09-28', '31310.09'),
#  ('Classic Legends Inc.', '2004-12-07', '25505.98'),
#  ('Classic Legends Inc.', '2003-04-16', '21665.98'),
#  ('Classic Legends Inc.', '2003-10-31', '22042.37'),
#  ('Gift Ideas Corp.', '2003-09-15', '6631.36'),
#  ('Gift Ideas Corp.', '2003-06-25', '17032.29'),
#  ('Gift Ideas Corp.', '2004-12-17', '26304.13'),
#  ('Scandinavian Gift Ideas', '2005-04-18', '27966.54'),
#  ('Scandinavian Gift Ideas', '2004-09-30', '48809.90'),
#  ('The Sharp Gifts Warehouse', '2004-06-21', '59551.38'),
#  ('Mini Auto Werke', '2003-11-15', '27121.90'),
#  ('Mini Auto Werke', '2003-11-20', '15130.97'),
#  ('Mini Auto Werke', '2005-05-03', '8807.12'),
#  ('Super Scale Inc.', '2003-12-05', '38139.18'),
#  ('Super Scale Inc.', '2004-05-12', '32239.47'),
#  ('Microscale Inc.', '2004-11-13', '27550.51'),
#  ('Microscale Inc.', '2004-04-30', '1679.92'),
#  ('Corrida Auto Replicas, Ltd', '2004-11-15', '33145.56'),
#  ('Corrida Auto Replicas, Ltd', '2004-02-06', '22162.61'),
#  ('Corrida Auto Replicas, Ltd', '2003-06-13', '57131.92'),
#  ('FunGiftIdeas.com', '2005-04-15', '30293.77'),
#  ('FunGiftIdeas.com', '2003-11-08', '9977.85'),
#  ('FunGiftIdeas.com', '2004-11-27', '48355.87'),
#  ('Australian Collectables, Ltd', '2004-07-28', '9415.13'),
#  ('Australian Collectables, Ltd', '2003-12-10', '35505.63'),
#  ('Frau da Collezione', '2004-02-17', '7612.06'),
#  ('Frau da Collezione', '2003-10-27', '17746.26'),
#  ('West Coast Collectables Co.', '2003-12-09', '7678.25'),
#  ('West Coast Collectables Co.', '2004-02-13', '36070.47'),
#  ('Iberia Gift Imports, Corp.', '2004-10-26', '3474.66'),
#  ('Iberia Gift Imports, Corp.', '2003-11-29', '47513.19'),
#  ('Motor Mint Distributors Inc.', '2004-04-14', '5899.38'),
#  ('Motor Mint Distributors Inc.', '2004-11-23', '45994.07'),
#  ('Motor Mint Distributors Inc.', '2003-03-20', '25833.14'),
#  ('Signal Collectibles Ltd.', '2003-09-28', '29997.09'),
#  ('Signal Collectibles Ltd.', '2004-02-29', '12573.28'),
#  ('Double Decker Gift Stores, Ltd', '2003-12-04', '22275.73'),
#  ('Double Decker Gift Stores, Ltd', '2004-01-31', '7310.42'),
#  ('Diecast Collectables', '2003-12-26', '59265.14'),
#  ('Diecast Collectables', '2004-05-14', '6276.60'),
#  ("Kelly's Gift Shop", '2005-05-25', '30253.75'),
#  ("Kelly's Gift Shop", '2003-07-16', '32077.44'),
#  ("Kelly's Gift Shop", '2004-12-31', '52166.00')]

# %% [markdown]
# Name of the top 5 most ordered product?

# %%
cur.execute('''
Select productName, quantityOrdered from products JOIN orderdetails using(productCode) GROUP BY productName ORDER BY quantityOrdered DESC LIMIT 5
''').fetchall()
# Out:
# [('1969 Dodge Charger', '97'),
#  ('1969 Dodge Super Bee', '90'),
#  ('America West Airlines B757-200', '85'),
#  ('1970 Plymouth Hemi Cuda', '77'),
#  ('F/A 18 Hornet 1/72', '77')]

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
cur.execute('''
Select lastname, firstname, productName 
FROM employees e 
JOIN customers c ON e.employeeNumber = c.salesRepEmployeeNumber
JOIN orders o ON c.customerNumber = o.customerNumber
JOIN orderdetails d ON o.orderNumber = d.orderNumber
JOIN products p ON d.productCode = p.productCode

''').fetchall()
# Out:
# [('Jennings', 'Leslie', '1958 Setra Bus'),
#  ('Jennings', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Jennings', 'Leslie', '1939 Cadillac Limousine'),
#  ('Jennings', 'Leslie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Jennings', 'Leslie', '1968 Ford Mustang'),
#  ('Jennings', 'Leslie', '1968 Dodge Charger'),
#  ('Jennings', 'Leslie', '1970 Plymouth Hemi Cuda'),
#  ('Jennings', 'Leslie', '1969 Dodge Charger'),
#  ('Jennings', 'Leslie', '1948 Porsche 356-A Roadster'),
#  ('Jennings', 'Leslie', '1969 Dodge Super Bee'),
#  ('Jennings', 'Leslie', '1976 Ford Gran Torino'),
#  ('Jennings', 'Leslie', '1957 Vespa GS150'),
#  ('Jennings', 'Leslie', '1957 Corvette Convertible'),
#  ('Jennings', 'Leslie', '1982 Ducati 900 Monster'),
#  ('Jennings', 'Leslie', '1982 Lamborghini Diablo'),
#  ('Jennings', 'Leslie', '1971 Alpine Renault 1600s'),
#  ('Jennings', 'Leslie', '1956 Porsche 356A Coupe'),
#  ('Jennings', 'Leslie', '1961 Chevrolet Impala'),
#  ('Jennings', 'Leslie', '1982 Ducati 996 R'),
#  ('Jennings', 'Leslie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Jennings', 'Leslie', '2002 Yamaha YZR M1'),
#  ('Jennings', 'Leslie', '2001 Ferrari Enzo'),
#  ('Jennings', 'Leslie', '1969 Corvair Monza'),
#  ('Jennings', 'Leslie', '1969 Ford Falcon'),
#  ('Jennings', 'Leslie', '1903 Ford Model A'),
#  ('Jennings', 'Leslie', 'Collectable Wooden Train'),
#  ('Jennings', 'Leslie', '1970 Triumph Spitfire'),
#  ('Jennings', 'Leslie', '1904 Buick Runabout'),
#  ('Jennings', 'Leslie', '18th century schooner'),
#  ('Jennings', 'Leslie', '1912 Ford Model T Delivery Wagon'),
#  ('Jennings', 'Leslie', "1950's Chicago Surface Lines Streetcar"),
#  ('Jennings', 'Leslie', '1962 City of Detroit Streetcar'),
#  ('Jennings', 'Leslie', 'The Schooner Bluenose'),
#  ('Jennings', 'Leslie', 'The Mayflower'),
#  ('Jennings', 'Leslie', 'The Titanic'),
#  ('Jennings', 'Leslie', 'The Queen Mary'),
#  ('Jennings', 'Leslie', 'Pont Yacht'),
#  ('Jennings', 'Leslie', '1937 Lincoln Berline'),
#  ('Jennings', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Jennings', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Jennings', 'Leslie', '1911 Ford Town Car'),
#  ('Jennings', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Jennings', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Jennings', 'Leslie', '1957 Ford Thunderbird'),
#  ('Jennings', 'Leslie', '1970 Chevy Chevelle SS 454'),
#  ('Jennings', 'Leslie', '1939 Chevrolet Deluxe Coupe'),
#  ('Jennings', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Jennings', 'Leslie', '1949 Jaguar XK 120'),
#  ('Jennings', 'Leslie', '1952 Citroen-15CV'),
#  ('Jennings', 'Leslie', '1969 Chevrolet Camaro Z28'),
#  ('Jennings', 'Leslie', '2002 Chevy Corvette'),
#  ('Jennings', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Jennings', 'Leslie', '1962 LanciaA Delta 16V'),
#  ('Jennings', 'Leslie', '1958 Setra Bus'),
#  ('Jennings', 'Leslie', '1957 Chevy Pickup'),
#  ('Jennings', 'Leslie', '1964 Mercedes Tour Bus'),
#  ('Jennings', 'Leslie', '1926 Ford Fire Engine'),
#  ('Jennings', 'Leslie', '1992 Ferrari 360 Spider red'),
#  ('Jennings', 'Leslie', '1940s Ford truck'),
#  ('Jennings', 'Leslie', '1939 Cadillac Limousine'),
#  ('Jennings', 'Leslie', '1962 Volkswagen Microbus'),
#  ('Jennings', 'Leslie', '1958 Chevy Corvette Limited Edition'),
#  ('Jennings', 'Leslie', '1980’s GM Manhattan Express'),
#  ('Jennings', 'Leslie', '1954 Greyhound Scenicruiser'),
#  ('Jennings', 'Leslie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Jennings', 'Leslie', '1982 Camaro Z28'),
#  ('Jennings', 'Leslie', '1957 Chevy Pickup'),
#  ('Jennings', 'Leslie', '1998 Chrysler Plymouth Prowler'),
#  ('Jennings', 'Leslie', '1964 Mercedes Tour Bus'),
#  ('Jennings', 'Leslie', '1926 Ford Fire Engine'),
#  ('Jennings', 'Leslie', '1992 Ferrari 360 Spider red'),
#  ('Jennings', 'Leslie', '1970 Dodge Coronet'),
#  ('Jennings', 'Leslie', '1962 Volkswagen Microbus'),
#  ('Jennings', 'Leslie', '1958 Chevy Corvette Limited Edition'),
#  ('Jennings', 'Leslie', '1992 Porsche Cayenne Turbo Silver'),
#  ('Jennings', 'Leslie', '1954 Greyhound Scenicruiser'),
#  ('Jennings', 'Leslie', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Jennings', 'Leslie', '2001 Ferrari Enzo'),
#  ('Jennings', 'Leslie', '1969 Corvair Monza'),
#  ('Jennings', 'Leslie', '1969 Ford Falcon'),
#  ('Jennings', 'Leslie', '1998 Chrysler Plymouth Prowler'),
#  ('Jennings', 'Leslie', '1903 Ford Model A'),
#  ('Jennings', 'Leslie', 'Collectable Wooden Train'),
#  ('Jennings', 'Leslie', '1970 Triumph Spitfire'),
#  ('Jennings', 'Leslie', '1970 Dodge Coronet'),
#  ('Jennings', 'Leslie', '1992 Porsche Cayenne Turbo Silver'),
#  ('Jennings', 'Leslie', "1950's Chicago Surface Lines Streetcar"),
#  ('Jennings', 'Leslie', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Jennings', 'Leslie', '1962 City of Detroit Streetcar'),
#  ('Jennings', 'Leslie', 'The Mayflower'),
#  ('Jennings', 'Leslie', '1952 Alpine Renault 1300'),
#  ('Jennings', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Jennings', 'Leslie', '1937 Lincoln Berline'),
#  ('Jennings', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Jennings', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Jennings', 'Leslie', '1911 Ford Town Car'),
#  ('Jennings', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Jennings', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Jennings', 'Leslie', '1913 Ford Model T Speedster'),
#  ('Jennings', 'Leslie', '1934 Ford V8 Coupe'),
#  ('Jennings', 'Leslie', '18th Century Vintage Horse Carriage'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1939 Cadillac Limousine'),
#  ('Jennings', 'Leslie', '1939 Chevrolet Deluxe Coupe'),
#  ('Jennings', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Jennings', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Jennings', 'Leslie', '1936 Chrysler Airflow'),
#  ('Jennings', 'Leslie', '1958 Chevy Corvette Limited Edition'),
#  ('Jennings', 'Leslie', '1980’s GM Manhattan Express'),
#  ('Jennings', 'Leslie', '1954 Greyhound Scenicruiser'),
#  ('Jennings', 'Leslie', '1952 Alpine Renault 1300'),
#  ('Jennings', 'Leslie', '1962 LanciaA Delta 16V'),
#  ('Jennings', 'Leslie', '1958 Setra Bus'),
#  ('Jennings', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Jennings', 'Leslie', '1926 Ford Fire Engine'),
#  ('Jennings', 'Leslie', '1913 Ford Model T Speedster'),
#  ('Jennings', 'Leslie', '1934 Ford V8 Coupe'),
#  ('Jennings', 'Leslie', '18th Century Vintage Horse Carriage'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1940s Ford truck'),
#  ('Jennings', 'Leslie', '1949 Jaguar XK 120'),
#  ('Jennings', 'Leslie', '1952 Citroen-15CV'),
#  ('Jennings', 'Leslie', '1969 Chevrolet Camaro Z28'),
#  ('Jennings', 'Leslie', '2002 Chevy Corvette'),
#  ('Jennings', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Jennings', 'Leslie', '2001 Ferrari Enzo'),
#  ('Jennings', 'Leslie', '1957 Chevy Pickup'),
#  ('Jennings', 'Leslie', '1998 Chrysler Plymouth Prowler'),
#  ('Jennings', 'Leslie', '1970 Dodge Coronet'),
#  ('Jennings', 'Leslie', '1962 Volkswagen Microbus'),
#  ('Jennings', 'Leslie', '1958 Chevy Corvette Limited Edition'),
#  ('Jennings', 'Leslie', '1992 Porsche Cayenne Turbo Silver'),
#  ('Jennings', 'Leslie', '1980’s GM Manhattan Express'),
#  ('Jennings', 'Leslie', '1954 Greyhound Scenicruiser'),
#  ('Jennings', 'Leslie', "1950's Chicago Surface Lines Streetcar"),
#  ('Jennings', 'Leslie', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Jennings', 'Leslie', '1982 Camaro Z28'),
#  ('Jennings', 'Leslie', '2001 Ferrari Enzo'),
#  ('Jennings', 'Leslie', '1969 Corvair Monza'),
#  ('Jennings', 'Leslie', '1969 Ford Falcon'),
#  ('Jennings', 'Leslie', '1957 Chevy Pickup'),
#  ('Jennings', 'Leslie', '1998 Chrysler Plymouth Prowler'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1940s Ford truck'),
#  ('Jennings', 'Leslie', '1939 Cadillac Limousine'),
#  ('Jennings', 'Leslie', '1962 Volkswagen Microbus'),
#  ('Jennings', 'Leslie', '1936 Chrysler Airflow'),
#  ('Jennings', 'Leslie', '1980’s GM Manhattan Express'),
#  ('Jennings', 'Leslie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Jennings', 'Leslie', '1982 Camaro Z28'),
#  ('Jennings', 'Leslie', '1940 Ford Delivery Sedan'),
#  ('Jennings', 'Leslie', 'The Schooner Bluenose'),
#  ('Jennings', 'Leslie', '1993 Mazda RX-7'),
#  ('Jennings', 'Leslie', '1995 Honda Civic'),
#  ('Jennings', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Jennings', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Jennings', 'Leslie', '1969 Dodge Super Bee'),
#  ('Jennings', 'Leslie', '1976 Ford Gran Torino'),
#  ('Jennings', 'Leslie', '1957 Vespa GS150'),
#  ('Jennings', 'Leslie', '1957 Corvette Convertible'),
#  ('Jennings', 'Leslie', '1982 Ducati 900 Monster'),
#  ('Jennings', 'Leslie', '1982 Lamborghini Diablo'),
#  ('Jennings', 'Leslie', '1971 Alpine Renault 1600s'),
#  ('Jennings', 'Leslie', '1956 Porsche 356A Coupe'),
#  ('Jennings', 'Leslie', '1961 Chevrolet Impala'),
#  ('Jennings', 'Leslie', '1982 Ducati 996 R'),
#  ('Jennings', 'Leslie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Jennings', 'Leslie', '2002 Yamaha YZR M1'),
#  ('Jennings', 'Leslie', '1969 Ford Falcon'),
#  ('Jennings', 'Leslie', '1903 Ford Model A'),
#  ('Jennings', 'Leslie', 'Collectable Wooden Train'),
#  ('Jennings', 'Leslie', '1904 Buick Runabout'),
#  ('Jennings', 'Leslie', '18th century schooner'),
#  ('Jennings', 'Leslie', '1912 Ford Model T Delivery Wagon'),
#  ('Jennings', 'Leslie', '1940 Ford Delivery Sedan'),
#  ('Jennings', 'Leslie', 'The Schooner Bluenose'),
#  ('Jennings', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Jennings', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Jennings', 'Leslie', '1937 Lincoln Berline'),
#  ('Jennings', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Jennings', 'Leslie', '1934 Ford V8 Coupe'),
#  ('Jennings', 'Leslie', '18th Century Vintage Horse Carriage'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1936 Chrysler Airflow'),
#  ('Jennings', 'Leslie', '1969 Harley Davidson Ultimate Chopper'),
#  ('Jennings', 'Leslie', '1996 Moto Guzzi 1100i'),
#  ('Jennings', 'Leslie', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Jennings', 'Leslie', '2002 Suzuki XREO'),
#  ('Jennings', 'Leslie', '1936 Harley Davidson El Knucklehead'),
#  ('Jennings', 'Leslie', '1997 BMW R 1100 S'),
#  ('Jennings', 'Leslie', '1960 BSA Gold Star DBD34'),
#  ('Jennings', 'Leslie', '1952 Alpine Renault 1300'),
#  ('Jennings', 'Leslie', '1958 Setra Bus'),
#  ('Jennings', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Jennings', 'Leslie', '1913 Ford Model T Speedster'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1939 Cadillac Limousine'),
#  ('Jennings', 'Leslie', '1936 Chrysler Airflow'),
#  ('Jennings', 'Leslie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Jennings', 'Leslie', '1952 Alpine Renault 1300'),
#  ('Jennings', 'Leslie', '1962 LanciaA Delta 16V'),
#  ('Jennings', 'Leslie', '1958 Setra Bus'),
#  ('Jennings', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Jennings', 'Leslie', '1926 Ford Fire Engine'),
#  ('Jennings', 'Leslie', '1940s Ford truck'),
#  ('Jennings', 'Leslie', '1939 Cadillac Limousine'),
#  ('Jennings', 'Leslie', '1962 Volkswagen Microbus'),
#  ('Jennings', 'Leslie', '1980’s GM Manhattan Express'),
#  ('Jennings', 'Leslie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Jennings', 'Leslie', '1982 Camaro Z28'),
#  ('Jennings', 'Leslie', '1969 Harley Davidson Ultimate Chopper'),
#  ('Jennings', 'Leslie', '1996 Moto Guzzi 1100i'),
#  ('Jennings', 'Leslie', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Jennings', 'Leslie', 'P-51-D Mustang'),
#  ('Jennings', 'Leslie', '1936 Harley Davidson El Knucklehead'),
#  ('Jennings', 'Leslie', '1997 BMW R 1100 S'),
#  ('Jennings', 'Leslie', '1928 British Royal Navy Airplane'),
#  ('Jennings', 'Leslie', '1960 BSA Gold Star DBD34'),
#  ('Jennings', 'Leslie', 'Corsair F4U ( Bird Cage)'),
#  ('Jennings', 'Leslie', '1900s Vintage Tri-Plane'),
#  ('Jennings', 'Leslie', '1997 BMW F650 ST'),
#  ('Jennings', 'Leslie', '1928 Ford Phaeton Deluxe'),
#  ('Jennings', 'Leslie', '1930 Buick Marquette Phaeton'),
#  ('Jennings', 'Leslie', 'American Airlines: B767-300'),
#  ('Jennings', 'Leslie', 'America West Airlines B757-200'),
#  ('Jennings', 'Leslie', 'ATA: B757-300'),
#  ('Jennings', 'Leslie', 'F/A 18 Hornet 1/72'),
#  ('Jennings', 'Leslie', 'American Airlines: MD-11S'),
#  ('Jennings', 'Leslie', '1900s Vintage Tri-Plane'),
#  ('Jennings', 'Leslie', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Jennings', 'Leslie', '2002 Suzuki XREO'),
#  ('Jennings', 'Leslie', '1936 Harley Davidson El Knucklehead'),
#  ('Jennings', 'Leslie', '1997 BMW R 1100 S'),
#  ('Jennings', 'Leslie', '1969 Harley Davidson Ultimate Chopper'),
#  ('Jennings', 'Leslie', '1996 Moto Guzzi 1100i'),
#  ('Jennings', 'Leslie', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Jennings', 'Leslie', '1968 Ford Mustang'),
#  ('Jennings', 'Leslie', '2002 Suzuki XREO'),
#  ('Jennings', 'Leslie', '1970 Plymouth Hemi Cuda'),
#  ('Jennings', 'Leslie', '1936 Harley Davidson El Knucklehead'),
#  ('Jennings', 'Leslie', '1969 Dodge Super Bee'),
#  ('Jennings', 'Leslie', '1976 Ford Gran Torino'),
#  ('Jennings', 'Leslie', '1957 Vespa GS150'),
#  ('Jennings', 'Leslie', '1957 Corvette Convertible'),
#  ('Jennings', 'Leslie', '1997 BMW R 1100 S'),
#  ('Jennings', 'Leslie', '1982 Ducati 900 Monster'),
#  ('Jennings', 'Leslie', '1971 Alpine Renault 1600s'),
#  ('Jennings', 'Leslie', '1961 Chevrolet Impala'),
#  ('Jennings', 'Leslie', '1982 Ducati 996 R'),
#  ('Jennings', 'Leslie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Jennings', 'Leslie', '2002 Yamaha YZR M1'),
#  ('Jennings', 'Leslie', '1937 Lincoln Berline'),
#  ('Jennings', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Jennings', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Jennings', 'Leslie', '1911 Ford Town Car'),
#  ('Jennings', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Jennings', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Jennings', 'Leslie', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Jennings', 'Leslie', '1939 Chevrolet Deluxe Coupe'),
#  ('Jennings', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Jennings', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Jennings', 'Leslie', '1952 Alpine Renault 1300'),
#  ('Jennings', 'Leslie', '1962 LanciaA Delta 16V'),
#  ('Jennings', 'Leslie', '1958 Setra Bus'),
#  ('Jennings', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Jennings', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Jennings', 'Leslie', '1926 Ford Fire Engine'),
#  ('Jennings', 'Leslie', '1913 Ford Model T Speedster'),
#  ('Jennings', 'Leslie', '1934 Ford V8 Coupe'),
#  ('Jennings', 'Leslie', '18th Century Vintage Horse Carriage'),
#  ('Jennings', 'Leslie', '1972 Alfa Romeo GTA'),
#  ('Jennings', 'Leslie', '18th century schooner'),
#  ('Jennings', 'Leslie', '1912 Ford Model T Delivery Wagon'),
#  ('Jennings', 'Leslie', 'The Mayflower'),
#  ('Jennings', 'Leslie', '1980s Black Hawk Helicopter'),
#  ('Jennings', 'Leslie', 'P-51-D Mustang'),
#  ('Jennings', 'Leslie', '1928 British Royal Navy Airplane'),
#  ('Jennings', 'Leslie', '1960 BSA Gold Star DBD34'),
#  ('Jennings', 'Leslie', 'Corsair F4U ( Bird Cage)'),
#  ('Jennings', 'Leslie', '1900s Vintage Tri-Plane'),
#  ('Jennings', 'Leslie', '1997 BMW F650 ST'),
#  ('Jennings', 'Leslie', '1928 Ford Phaeton Deluxe'),
#  ('Jennings', 'Leslie', '1930 Buick Marquette Phaeton'),
#  ('Jennings', 'Leslie', 'American Airlines: B767-300'),
#  ('Jennings', 'Leslie', 'America West Airlines B757-200'),
#  ('Jennings', 'Leslie', 'ATA: B757-300'),
#  ('Jennings', 'Leslie', 'F/A 18 Hornet 1/72'),
#  ('Jennings', 'Leslie', 'American Airlines: MD-11S'),
#  ('Jennings', 'Leslie', '1913 Ford Model T Speedster'),
#  ('Jennings', 'Leslie', '1934 Ford V8 Coupe'),
#  ('Jennings', 'Leslie', '18th Century Vintage Horse Carriage'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1936 Chrysler Airflow'),
#  ('Jennings', 'Leslie', '1972 Alfa Romeo GTA'),
#  ('Jennings', 'Leslie', '1980s Black Hawk Helicopter'),
#  ('Jennings', 'Leslie', '1999 Yamaha Speed Boat'),
#  ('Jennings', 'Leslie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Jennings', 'Leslie', '1900s Vintage Bi-Plane'),
#  ('Jennings', 'Leslie', '1937 Horch 930V Limousine'),
#  ('Jennings', 'Leslie', '1940 Ford Delivery Sedan'),
#  ('Jennings', 'Leslie', 'HMS Bounty'),
#  ('Jennings', 'Leslie', 'Boeing X-32A JSF'),
#  ('Jennings', 'Leslie', '1965 Aston Martin DB5'),
#  ('Jennings', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Jennings', 'Leslie', '1911 Ford Town Car'),
#  ('Jennings', 'Leslie', '1999 Indy 500 Monte Carlo SS'),
#  ('Jennings', 'Leslie', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Jennings', 'Leslie', '1957 Ford Thunderbird'),
#  ('Jennings', 'Leslie', '1970 Chevy Chevelle SS 454'),
#  ('Jennings', 'Leslie', '1966 Shelby Cobra 427 S/C'),
#  ('Jennings', 'Leslie', '1949 Jaguar XK 120'),
#  ('Jennings', 'Leslie', '1952 Citroen-15CV'),
#  ('Jennings', 'Leslie', '1969 Chevrolet Camaro Z28'),
#  ('Jennings', 'Leslie', '2002 Chevy Corvette'),
#  ('Jennings', 'Leslie', '1937 Lincoln Berline'),
#  ('Jennings', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Jennings', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Jennings', 'Leslie', '1911 Ford Town Car'),
#  ('Jennings', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Jennings', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Jennings', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Jennings', 'Leslie', '1939 Chevrolet Deluxe Coupe'),
#  ('Jennings', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Jennings', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Jennings', 'Leslie', '1936 Chrysler Airflow'),
#  ('Jennings', 'Leslie', '1957 Chevy Pickup'),
#  ('Jennings', 'Leslie', '1998 Chrysler Plymouth Prowler'),
#  ('Jennings', 'Leslie', '1958 Chevy Corvette Limited Edition'),
#  ('Jennings', 'Leslie', '1954 Greyhound Scenicruiser'),
#  ('Thompson', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Thompson', 'Leslie', '1911 Ford Town Car'),
#  ('Thompson', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Thompson', 'Leslie', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Thompson', 'Leslie', '1957 Ford Thunderbird'),
#  ('Thompson', 'Leslie', '1970 Chevy Chevelle SS 454'),
#  ('Thompson', 'Leslie', '1939 Chevrolet Deluxe Coupe'),
#  ('Thompson', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Thompson', 'Leslie', '1949 Jaguar XK 120'),
#  ('Thompson', 'Leslie', '1952 Citroen-15CV'),
#  ('Thompson', 'Leslie', '1969 Chevrolet Camaro Z28'),
#  ('Thompson', 'Leslie', '2002 Chevy Corvette'),
#  ('Thompson', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Thompson', 'Leslie', '1993 Mazda RX-7'),
#  ('Thompson', 'Leslie', '1965 Aston Martin DB5'),
#  ('Thompson', 'Leslie', '1948 Porsche 356-A Roadster'),
#  ('Thompson', 'Leslie', '1995 Honda Civic'),
#  ('Thompson', 'Leslie', '1999 Indy 500 Monte Carlo SS'),
#  ('Thompson', 'Leslie', '1992 Ferrari 360 Spider red'),
#  ('Thompson', 'Leslie', '1948 Porsche Type 356 Roadster'),
#  ('Thompson', 'Leslie', '1966 Shelby Cobra 427 S/C'),
#  ('Thompson', 'Leslie', '1982 Lamborghini Diablo'),
#  ('Thompson', 'Leslie', '1956 Porsche 356A Coupe'),
#  ('Thompson', 'Leslie', '1937 Lincoln Berline'),
#  ('Thompson', 'Leslie', '1949 Jaguar XK 120'),
#  ('Thompson', 'Leslie', '1952 Citroen-15CV'),
#  ('Thompson', 'Leslie', '1969 Chevrolet Camaro Z28'),
#  ('Thompson', 'Leslie', '2002 Chevy Corvette'),
#  ('Thompson', 'Leslie', '1936 Mercedes Benz 500k Roadster'),
#  ('Thompson', 'Leslie', '1969 Harley Davidson Ultimate Chopper'),
#  ('Thompson', 'Leslie', '1996 Moto Guzzi 1100i'),
#  ('Thompson', 'Leslie', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Thompson', 'Leslie', '2002 Suzuki XREO'),
#  ('Thompson', 'Leslie', 'P-51-D Mustang'),
#  ('Thompson', 'Leslie', '1936 Harley Davidson El Knucklehead'),
#  ('Thompson', 'Leslie', '1997 BMW R 1100 S'),
#  ('Thompson', 'Leslie', '1928 British Royal Navy Airplane'),
#  ('Thompson', 'Leslie', '1960 BSA Gold Star DBD34'),
#  ('Thompson', 'Leslie', '1982 Ducati 900 Monster'),
#  ('Thompson', 'Leslie', '1900s Vintage Tri-Plane'),
#  ('Thompson', 'Leslie', '1997 BMW F650 ST'),
#  ('Thompson', 'Leslie', '1982 Ducati 996 R'),
#  ('Thompson', 'Leslie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Thompson', 'Leslie', '2002 Yamaha YZR M1'),
#  ('Thompson', 'Leslie', 'ATA: B757-300'),
#  ('Thompson', 'Leslie', '2002 Suzuki XREO'),
#  ('Thompson', 'Leslie', '1965 Aston Martin DB5'),
#  ('Thompson', 'Leslie', '1917 Grand Touring Sedan'),
#  ('Thompson', 'Leslie', '1911 Ford Town Car'),
#  ('Thompson', 'Leslie', '1932 Model A Ford J-Coupe'),
#  ('Thompson', 'Leslie', '1928 Mercedes-Benz SSK'),
#  ('Thompson', 'Leslie', '1948 Porsche Type 356 Roadster'),
#  ('Thompson', 'Leslie', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Thompson', 'Leslie', '1957 Ford Thunderbird'),
#  ('Thompson', 'Leslie', '1970 Chevy Chevelle SS 454'),
#  ('Thompson', 'Leslie', '1966 Shelby Cobra 427 S/C'),
#  ('Thompson', 'Leslie', '1939 Chevrolet Deluxe Coupe'),
#  ('Thompson', 'Leslie', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Thompson', 'Leslie', '1982 Lamborghini Diablo'),
#  ('Thompson', 'Leslie', '1912 Ford Model T Delivery Wagon'),
#  ('Thompson', 'Leslie', 'The USS Constitution Ship'),
#  ('Thompson', 'Leslie', '1968 Dodge Charger'),
#  ('Thompson', 'Leslie', '1972 Alfa Romeo GTA'),
#  ('Thompson', 'Leslie', '1980s Black Hawk Helicopter'),
#  ('Thompson', 'Leslie', '1999 Yamaha Speed Boat'),
#  ('Thompson', 'Leslie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Thompson', 'Leslie', '1900s Vintage Bi-Plane'),
#  ('Thompson', 'Leslie', '1912 Ford Model T Delivery Wagon'),
#  ('Thompson', 'Leslie', '1937 Horch 930V Limousine'),
#  ('Thompson', 'Leslie', '1940 Ford Delivery Sedan'),
#  ('Thompson', 'Leslie', 'Corsair F4U ( Bird Cage)'),
#  ('Thompson', 'Leslie', 'The Schooner Bluenose'),
#  ('Thompson', 'Leslie', 'HMS Bounty'),
#  ('Thompson', 'Leslie', 'America West Airlines B757-200'),
#  ('Thompson', 'Leslie', 'The USS Constitution Ship'),
#  ('Thompson', 'Leslie', 'The Titanic'),
#  ('Thompson', 'Leslie', 'The Queen Mary'),
#  ('Thompson', 'Leslie', 'American Airlines: MD-11S'),
#  ('Thompson', 'Leslie', 'Boeing X-32A JSF'),
#  ('Thompson', 'Leslie', 'Pont Yacht'),
#  ('Thompson', 'Leslie', '1965 Aston Martin DB5'),
#  ('Thompson', 'Leslie', '1995 Honda Civic'),
#  ('Thompson', 'Leslie', '1999 Indy 500 Monte Carlo SS'),
#  ('Thompson', 'Leslie', '1948 Porsche Type 356 Roadster'),
#  ('Thompson', 'Leslie', '1970 Chevy Chevelle SS 454'),
#  ('Thompson', 'Leslie', '1966 Shelby Cobra 427 S/C'),
#  ('Thompson', 'Leslie', '2002 Chevy Corvette'),
#  ('Thompson', 'Leslie', '1968 Dodge Charger'),
#  ('Thompson', 'Leslie', '1969 Dodge Charger'),
#  ('Thompson', 'Leslie', '1948 Porsche 356-A Roadster'),
#  ('Thompson', 'Leslie', '1992 Ferrari 360 Spider red'),
#  ('Thompson', 'Leslie', '1982 Lamborghini Diablo'),
#  ('Thompson', 'Leslie', '1956 Porsche 356A Coupe'),
#  ('Thompson', 'Leslie', '1972 Alfa Romeo GTA'),
#  ('Thompson', 'Leslie', '1999 Yamaha Speed Boat'),
#  ('Thompson', 'Leslie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Thompson', 'Leslie', '1900s Vintage Bi-Plane'),
#  ('Thompson', 'Leslie', '1937 Horch 930V Limousine'),
#  ('Thompson', 'Leslie', '1940 Ford Delivery Sedan'),
#  ('Thompson', 'Leslie', 'HMS Bounty'),
#  ('Thompson', 'Leslie', 'Boeing X-32A JSF'),
#  ('Thompson', 'Leslie', '1930 Buick Marquette Phaeton'),
#  ('Thompson', 'Leslie', 'American Airlines: B767-300'),
#  ('Thompson', 'Leslie', 'F/A 18 Hornet 1/72'),
#  ('Thompson', 'Leslie', '1952 Alpine Renault 1300'),
#  ('Thompson', 'Leslie', '1940 Ford Pickup Truck'),
#  ('Thompson', 'Leslie', '1937 Lincoln Berline'),
#  ('Thompson', 'Leslie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Thompson', 'Leslie', '1913 Ford Model T Speedster'),
#  ('Thompson', 'Leslie', '1934 Ford V8 Coupe'),
#  ('Thompson', 'Leslie', '18th Century Vintage Horse Carriage'),
#  ('Thompson', 'Leslie', '1917 Maxwell Touring Car'),
#  ('Thompson', 'Leslie', '1939 Cadillac Limousine'),
#  ('Thompson', 'Leslie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1952 Alpine Renault 1300'),
#  ('Firrelli', 'Julie', '1940 Ford Pickup Truck'),
#  ('Firrelli', 'Julie', '1913 Ford Model T Speedster'),
#  ('Firrelli', 'Julie', '1934 Ford V8 Coupe'),
#  ('Firrelli', 'Julie', '18th Century Vintage Horse Carriage'),
#  ('Firrelli', 'Julie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', '1968 Ford Mustang'),
#  ('Firrelli', 'Julie', '2002 Suzuki XREO'),
#  ('Firrelli', 'Julie', '1968 Dodge Charger'),
#  ('Firrelli', 'Julie', '1970 Plymouth Hemi Cuda'),
#  ('Firrelli', 'Julie', '1969 Dodge Super Bee'),
#  ('Firrelli', 'Julie', '1976 Ford Gran Torino'),
#  ('Firrelli', 'Julie', '1957 Vespa GS150'),
#  ('Firrelli', 'Julie', '1957 Corvette Convertible'),
#  ('Firrelli', 'Julie', '1982 Ducati 900 Monster'),
#  ('Firrelli', 'Julie', '1971 Alpine Renault 1600s'),
#  ('Firrelli', 'Julie', '1961 Chevrolet Impala'),
#  ('Firrelli', 'Julie', '1982 Ducati 996 R'),
#  ('Firrelli', 'Julie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Firrelli', 'Julie', '2002 Yamaha YZR M1'),
#  ('Firrelli', 'Julie', 'The Queen Mary'),
#  ('Firrelli', 'Julie', '1972 Alfa Romeo GTA'),
#  ('Firrelli', 'Julie', '1980s Black Hawk Helicopter'),
#  ('Firrelli', 'Julie', '1999 Yamaha Speed Boat'),
#  ('Firrelli', 'Julie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', '1940 Ford Delivery Sedan'),
#  ('Firrelli', 'Julie', 'Corsair F4U ( Bird Cage)'),
#  ('Firrelli', 'Julie', '1930 Buick Marquette Phaeton'),
#  ('Firrelli', 'Julie', 'American Airlines: B767-300'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'America West Airlines B757-200'),
#  ('Firrelli', 'Julie', 'The USS Constitution Ship'),
#  ('Firrelli', 'Julie', 'F/A 18 Hornet 1/72'),
#  ('Firrelli', 'Julie', 'American Airlines: MD-11S'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', '2001 Ferrari Enzo'),
#  ('Firrelli', 'Julie', '1969 Corvair Monza'),
#  ('Firrelli', 'Julie', '1969 Ford Falcon'),
#  ('Firrelli', 'Julie', '1903 Ford Model A'),
#  ('Firrelli', 'Julie', 'Collectable Wooden Train'),
#  ('Firrelli', 'Julie', '1970 Triumph Spitfire'),
#  ('Firrelli', 'Julie', '1904 Buick Runabout'),
#  ('Firrelli', 'Julie', '18th century schooner'),
#  ('Firrelli', 'Julie', '1912 Ford Model T Delivery Wagon'),
#  ('Firrelli', 'Julie', '1962 City of Detroit Streetcar'),
#  ('Firrelli', 'Julie', 'The Schooner Bluenose'),
#  ('Firrelli', 'Julie', 'The Mayflower'),
#  ('Firrelli', 'Julie', 'The USS Constitution Ship'),
#  ('Firrelli', 'Julie', 'The Titanic'),
#  ('Firrelli', 'Julie', 'The Queen Mary'),
#  ('Firrelli', 'Julie', 'Pont Yacht'),
#  ('Firrelli', 'Julie', '1993 Mazda RX-7'),
#  ('Firrelli', 'Julie', '1974 Ducati 350 Mk3 Desmo'),
#  ('Firrelli', 'Julie', '2002 Yamaha YZR M1'),
#  ('Firrelli', 'Julie', '1952 Alpine Renault 1300'),
#  ('Firrelli', 'Julie', '1962 LanciaA Delta 16V'),
#  ('Firrelli', 'Julie', '1958 Setra Bus'),
#  ('Firrelli', 'Julie', '1940 Ford Pickup Truck'),
#  ('Firrelli', 'Julie', '1913 Ford Model T Speedster'),
#  ('Firrelli', 'Julie', '1934 Ford V8 Coupe'),
#  ('Firrelli', 'Julie', '18th Century Vintage Horse Carriage'),
#  ('Firrelli', 'Julie', '1940s Ford truck'),
#  ('Firrelli', 'Julie', '1939 Cadillac Limousine'),
#  ('Firrelli', 'Julie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Firrelli', 'Julie', '1982 Camaro Z28'),
#  ('Firrelli', 'Julie', '1972 Alfa Romeo GTA'),
#  ('Firrelli', 'Julie', '1980s Black Hawk Helicopter'),
#  ('Firrelli', 'Julie', '1999 Yamaha Speed Boat'),
#  ('Firrelli', 'Julie', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', '1940 Ford Delivery Sedan'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', '1968 Ford Mustang'),
#  ('Firrelli', 'Julie', '1968 Dodge Charger'),
#  ('Firrelli', 'Julie', '1970 Plymouth Hemi Cuda'),
#  ('Firrelli', 'Julie', '1969 Dodge Charger'),
#  ('Firrelli', 'Julie', '1948 Porsche 356-A Roadster'),
#  ('Firrelli', 'Julie', '1969 Dodge Super Bee'),
#  ('Firrelli', 'Julie', '1976 Ford Gran Torino'),
#  ('Firrelli', 'Julie', '1982 Lamborghini Diablo'),
#  ('Firrelli', 'Julie', '1971 Alpine Renault 1600s'),
#  ('Firrelli', 'Julie', '1956 Porsche 356A Coupe'),
#  ('Firrelli', 'Julie', '1961 Chevrolet Impala'),
#  ('Firrelli', 'Julie', '1980s Black Hawk Helicopter'),
#  ('Firrelli', 'Julie', '1900s Vintage Bi-Plane'),
#  ('Firrelli', 'Julie', '1937 Horch 930V Limousine'),
#  ('Firrelli', 'Julie', 'HMS Bounty'),
#  ('Firrelli', 'Julie', 'Boeing X-32A JSF'),
#  ('Firrelli', 'Julie', '1952 Alpine Renault 1300'),
#  ('Firrelli', 'Julie', '1937 Lincoln Berline'),
#  ('Firrelli', 'Julie', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Firrelli', 'Julie', '1913 Ford Model T Speedster'),
#  ('Firrelli', 'Julie', '1934 Ford V8 Coupe'),
#  ('Firrelli', 'Julie', '18th Century Vintage Horse Carriage'),
#  ('Firrelli', 'Julie', '1917 Maxwell Touring Car'),
#  ('Firrelli', 'Julie', '1936 Chrysler Airflow'),
#  ('Firrelli', 'Julie', '1962 LanciaA Delta 16V'),
#  ('Firrelli', 'Julie', '1957 Chevy Pickup'),
#  ('Firrelli', 'Julie', '1998 Chrysler Plymouth Prowler'),
#  ('Firrelli', 'Julie', '1964 Mercedes Tour Bus'),
#  ('Firrelli', 'Julie', '1926 Ford Fire Engine'),
#  ('Firrelli', 'Julie', '1992 Ferrari 360 Spider red'),
#  ('Firrelli', 'Julie', '1970 Triumph Spitfire'),
#  ('Firrelli', 'Julie', '1940s Ford truck'),
#  ('Firrelli', 'Julie', '1970 Dodge Coronet'),
#  ('Firrelli', 'Julie', '1962 Volkswagen Microbus'),
#  ('Firrelli', 'Julie', '1958 Chevy Corvette Limited Edition'),
#  ('Firrelli', 'Julie', '1992 Porsche Cayenne Turbo Silver'),
#  ('Firrelli', 'Julie', '1980’s GM Manhattan Express'),
#  ('Firrelli', 'Julie', '1954 Greyhound Scenicruiser'),
#  ('Firrelli', 'Julie', "1950's Chicago Surface Lines Streetcar"),
#  ('Firrelli', 'Julie', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Firrelli', 'Julie', '1932 Model A Ford J-Coupe'),
#  ('Firrelli', 'Julie', '1939 Chevrolet Deluxe Coupe'),
#  ('Patterson', 'Steve', '2001 Ferrari Enzo'),
#  ('Patterson', 'Steve', '1969 Corvair Monza'),
#  ('Patterson', 'Steve', '1969 Ford Falcon'),
#  ('Patterson', 'Steve', '1970 Triumph Spitfire'),
#  ('Patterson', 'Steve', "1950's Chicago Surface Lines Streetcar"),
#  ('Patterson', 'Steve', '1962 City of Detroit Streetcar'),
#  ('Patterson', 'Steve', '1962 LanciaA Delta 16V'),
#  ('Patterson', 'Steve', '1958 Setra Bus'),
#  ('Patterson', 'Steve', '1957 Chevy Pickup'),
#  ('Patterson', 'Steve', '1964 Mercedes Tour Bus'),
#  ('Patterson', 'Steve', '1926 Ford Fire Engine'),
#  ('Patterson', 'Steve', '1992 Ferrari 360 Spider red'),
#  ('Patterson', 'Steve', '1940s Ford truck'),
#  ('Patterson', 'Steve', '1939 Cadillac Limousine'),
#  ('Patterson', 'Steve', '1962 Volkswagen Microbus'),
#  ('Patterson', 'Steve', '1958 Chevy Corvette Limited Edition'),
#  ('Patterson', 'Steve', '1980’s GM Manhattan Express'),
#  ('Patterson', 'Steve', '1954 Greyhound Scenicruiser'),
#  ('Patterson', 'Steve', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Patterson', 'Steve', '1982 Camaro Z28'),
#  ('Patterson', 'Steve', '1969 Harley Davidson Ultimate Chopper'),
#  ('Patterson', 'Steve', '1996 Moto Guzzi 1100i'),
#  ('Patterson', 'Steve', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Patterson', 'Steve', 'P-51-D Mustang'),
#  ('Patterson', 'Steve', '1936 Harley Davidson El Knucklehead'),
#  ('Patterson', 'Steve', '1997 BMW R 1100 S'),
#  ('Patterson', 'Steve', '1960 BSA Gold Star DBD34'),
#  ('Patterson', 'Steve', '1997 BMW F650 ST'),
#  ('Patterson', 'Steve', 'ATA: B757-300'),
#  ('Patterson', 'Steve', '1937 Lincoln Berline'),
#  ('Patterson', 'Steve', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Patterson', 'Steve', '1999 Yamaha Speed Boat'),
#  ('Patterson', 'Steve', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Patterson', 'Steve', '1917 Maxwell Touring Car'),
#  ('Patterson', 'Steve', '1936 Chrysler Airflow'),
#  ('Patterson', 'Steve', 'HMS Bounty'),
#  ('Patterson', 'Steve', 'America West Airlines B757-200'),
#  ('Patterson', 'Steve', 'American Airlines: MD-11S'),
#  ('Patterson', 'Steve', 'Boeing X-32A JSF'),
#  ('Patterson', 'Steve', '1969 Harley Davidson Ultimate Chopper'),
#  ('Patterson', 'Steve', '1996 Moto Guzzi 1100i'),
#  ('Patterson', 'Steve', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Patterson', 'Steve', '2002 Suzuki XREO'),
#  ('Patterson', 'Steve', '1936 Harley Davidson El Knucklehead'),
#  ('Patterson', 'Steve', '1997 BMW R 1100 S'),
#  ('Patterson', 'Steve', '1960 BSA Gold Star DBD34'),
#  ('Patterson', 'Steve', '1982 Ducati 900 Monster'),
#  ('Patterson', 'Steve', '1997 BMW F650 ST'),
#  ('Patterson', 'Steve', '1982 Ducati 996 R'),
#  ('Patterson', 'Steve', '1974 Ducati 350 Mk3 Desmo'),
#  ('Patterson', 'Steve', '2002 Yamaha YZR M1'),
#  ('Patterson', 'Steve', 'ATA: B757-300'),
#  ('Patterson', 'Steve', '1962 LanciaA Delta 16V'),
#  ('Patterson', 'Steve', '1957 Chevy Pickup'),
#  ('Patterson', 'Steve', '1998 Chrysler Plymouth Prowler'),
#  ('Patterson', 'Steve', '1964 Mercedes Tour Bus'),
#  ('Patterson', 'Steve', '1926 Ford Fire Engine'),
#  ('Patterson', 'Steve', '1992 Ferrari 360 Spider red'),
#  ('Patterson', 'Steve', '1940s Ford truck'),
#  ('Patterson', 'Steve', '1970 Dodge Coronet'),
#  ('Patterson', 'Steve', '1962 Volkswagen Microbus'),
#  ('Patterson', 'Steve', '1958 Chevy Corvette Limited Edition'),
#  ('Patterson', 'Steve', '1992 Porsche Cayenne Turbo Silver'),
#  ('Patterson', 'Steve', '1980’s GM Manhattan Express'),
#  ('Patterson', 'Steve', '1954 Greyhound Scenicruiser'),
#  ('Patterson', 'Steve', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Patterson', 'Steve', '1957 Vespa GS150'),
#  ('Patterson', 'Steve', '1957 Corvette Convertible'),
#  ('Patterson', 'Steve', '1982 Ducati 900 Monster'),
#  ('Patterson', 'Steve', '1961 Chevrolet Impala'),
#  ('Patterson', 'Steve', '1982 Ducati 996 R'),
#  ('Patterson', 'Steve', '1974 Ducati 350 Mk3 Desmo'),
#  ('Patterson', 'Steve', '2002 Yamaha YZR M1'),
#  ('Patterson', 'Steve', '1972 Alfa Romeo GTA'),
#  ('Patterson', 'Steve', '1912 Ford Model T Delivery Wagon'),
#  ('Patterson', 'Steve', 'The Schooner Bluenose'),
#  ('Patterson', 'Steve', 'The USS Constitution Ship'),
#  ('Patterson', 'Steve', 'The Titanic'),
#  ('Patterson', 'Steve', '1972 Alfa Romeo GTA'),
#  ('Patterson', 'Steve', '1999 Yamaha Speed Boat'),
#  ('Patterson', 'Steve', '1903 Ford Model A'),
#  ('Patterson', 'Steve', 'Collectable Wooden Train'),
#  ('Patterson', 'Steve', '1904 Buick Runabout'),
#  ('Patterson', 'Steve', '18th century schooner'),
#  ('Patterson', 'Steve', '1912 Ford Model T Delivery Wagon'),
#  ('Patterson', 'Steve', '1940 Ford Delivery Sedan'),
#  ('Patterson', 'Steve', 'The Schooner Bluenose'),
#  ('Patterson', 'Steve', 'The Mayflower'),
#  ('Patterson', 'Steve', 'The USS Constitution Ship'),
#  ('Patterson', 'Steve', 'The Titanic'),
#  ('Patterson', 'Steve', 'The Queen Mary'),
#  ('Patterson', 'Steve', 'Pont Yacht'),
#  ('Patterson', 'Steve', '1917 Grand Touring Sedan'),
#  ('Patterson', 'Steve', '1911 Ford Town Car'),
#  ('Patterson', 'Steve', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Patterson', 'Steve', '1936 Mercedes Benz 500k Roadster'),
#  ('Patterson', 'Steve', '1969 Dodge Charger'),
#  ('Patterson', 'Steve', '1993 Mazda RX-7'),
#  ('Patterson', 'Steve', '1965 Aston Martin DB5'),
#  ('Patterson', 'Steve', '1948 Porsche 356-A Roadster'),
#  ('Patterson', 'Steve', '1995 Honda Civic'),
#  ('Patterson', 'Steve', '1999 Indy 500 Monte Carlo SS'),
#  ('Patterson', 'Steve', '1992 Ferrari 360 Spider red'),
#  ('Patterson', 'Steve', '1948 Porsche Type 356 Roadster'),
#  ('Patterson', 'Steve', '1970 Chevy Chevelle SS 454'),
#  ('Patterson', 'Steve', '1966 Shelby Cobra 427 S/C'),
#  ('Patterson', 'Steve', '1949 Jaguar XK 120'),
#  ('Patterson', 'Steve', '1952 Citroen-15CV'),
#  ('Patterson', 'Steve', '1982 Lamborghini Diablo'),
#  ('Patterson', 'Steve', '1969 Chevrolet Camaro Z28'),
#  ('Patterson', 'Steve', '2002 Chevy Corvette'),
#  ('Patterson', 'Steve', '1956 Porsche 356A Coupe'),
#  ('Patterson', 'Steve', '1952 Alpine Renault 1300'),
#  ('Patterson', 'Steve', '1962 LanciaA Delta 16V'),
#  ('Patterson', 'Steve', '1958 Setra Bus'),
#  ('Patterson', 'Steve', '1940 Ford Pickup Truck'),
#  ('Patterson', 'Steve', '1937 Lincoln Berline'),
#  ('Patterson', 'Steve', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Patterson', 'Steve', '1932 Model A Ford J-Coupe'),
#  ('Patterson', 'Steve', '1926 Ford Fire Engine'),
#  ('Patterson', 'Steve', '1928 Mercedes-Benz SSK'),
#  ('Patterson', 'Steve', '1913 Ford Model T Speedster'),
#  ('Patterson', 'Steve', '1934 Ford V8 Coupe'),
#  ('Patterson', 'Steve', '18th Century Vintage Horse Carriage'),
#  ('Patterson', 'Steve', '1939 Chevrolet Deluxe Coupe'),
#  ('Patterson', 'Steve', '1938 Cadillac V-16 Presidential Limousine'),
#  ('Patterson', 'Steve', '1903 Ford Model A'),
#  ('Patterson', 'Steve', '1904 Buick Runabout'),
#  ('Patterson', 'Steve', 'The Mayflower'),
#  ('Patterson', 'Steve', '1969 Dodge Charger'),
#  ('Patterson', 'Steve', '1993 Mazda RX-7'),
#  ('Patterson', 'Steve', '1965 Aston Martin DB5'),
#  ('Patterson', 'Steve', '1948 Porsche 356-A Roadster'),
#  ('Patterson', 'Steve', '1995 Honda Civic'),
#  ('Patterson', 'Steve', '1999 Indy 500 Monte Carlo SS'),
#  ('Patterson', 'Steve', '1992 Ferrari 360 Spider red'),
#  ('Patterson', 'Steve', '1948 Porsche Type 356 Roadster'),
#  ('Patterson', 'Steve', '1970 Chevy Chevelle SS 454'),
#  ('Patterson', 'Steve', '1966 Shelby Cobra 427 S/C'),
#  ('Patterson', 'Steve', '1949 Jaguar XK 120'),
#  ('Patterson', 'Steve', '1982 Lamborghini Diablo'),
#  ('Patterson', 'Steve', '1969 Chevrolet Camaro Z28'),
#  ('Patterson', 'Steve', '2002 Chevy Corvette'),
#  ('Patterson', 'Steve', '1956 Porsche 356A Coupe'),
#  ('Patterson', 'Steve', '1969 Harley Davidson Ultimate Chopper'),
#  ('Patterson', 'Steve', '1996 Moto Guzzi 1100i'),
#  ('Patterson', 'Steve', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Patterson', 'Steve', '2002 Suzuki XREO'),
#  ('Patterson', 'Steve', '1928 Ford Phaeton Deluxe'),
#  ('Patterson', 'Steve', '1930 Buick Marquette Phaeton'),
#  ('Patterson', 'Steve', 'American Airlines: B767-300'),
#  ('Patterson', 'Steve', 'ATA: B757-300'),
#  ('Tseng', 'Foon Yue', '2001 Ferrari Enzo'),
#  ('Tseng', 'Foon Yue', '1969 Corvair Monza'),
#  ('Tseng', 'Foon Yue', '1969 Ford Falcon'),
#  ('Tseng', 'Foon Yue', '1957 Chevy Pickup'),
#  ('Tseng', 'Foon Yue', '1998 Chrysler Plymouth Prowler'),
#  ('Tseng', 'Foon Yue', '1964 Mercedes Tour Bus'),
#  ('Tseng', 'Foon Yue', '1992 Ferrari 360 Spider red'),
#  ('Tseng', 'Foon Yue', '1970 Triumph Spitfire'),
#  ('Tseng', 'Foon Yue', '1970 Dodge Coronet'),
#  ('Tseng', 'Foon Yue', '1958 Chevy Corvette Limited Edition'),
#  ('Tseng', 'Foon Yue', '1992 Porsche Cayenne Turbo Silver'),
#  ('Tseng', 'Foon Yue', '1954 Greyhound Scenicruiser'),
#  ('Tseng', 'Foon Yue', "1950's Chicago Surface Lines Streetcar"),
#  ('Tseng', 'Foon Yue', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Tseng', 'Foon Yue', '1962 City of Detroit Streetcar'),
#  ('Tseng', 'Foon Yue', '1993 Mazda RX-7'),
#  ('Tseng', 'Foon Yue', '1965 Aston Martin DB5'),
#  ('Tseng', 'Foon Yue', '1917 Grand Touring Sedan'),
#  ('Tseng', 'Foon Yue', '1995 Honda Civic'),
#  ('Tseng', 'Foon Yue', '1911 Ford Town Car'),
#  ('Tseng', 'Foon Yue', '1932 Model A Ford J-Coupe'),
#  ('Tseng', 'Foon Yue', '1999 Indy 500 Monte Carlo SS'),
#  ('Tseng', 'Foon Yue', '1948 Porsche Type 356 Roadster'),
#  ('Tseng', 'Foon Yue', '1932 Alfa Romeo 8C2300 Spider Sport'),
#  ('Tseng', 'Foon Yue', '1957 Ford Thunderbird'),
#  ('Tseng', 'Foon Yue', '1970 Chevy Chevelle SS 454'),
#  ('Tseng', 'Foon Yue', '1966 Shelby Cobra 427 S/C'),
#  ('Tseng', 'Foon Yue', '1949 Jaguar XK 120'),
#  ('Tseng', 'Foon Yue', '1952 Citroen-15CV'),
#  ('Tseng', 'Foon Yue', '1969 Chevrolet Camaro Z28'),
#  ('Tseng', 'Foon Yue', '2002 Chevy Corvette'),
#  ('Tseng', 'Foon Yue', '1936 Mercedes Benz 500k Roadster'),
#  ('Tseng', 'Foon Yue', '1957 Ford Thunderbird'),
#  ('Tseng', 'Foon Yue', '1970 Chevy Chevelle SS 454'),
#  ('Tseng', 'Foon Yue', '1949 Jaguar XK 120'),
#  ('Tseng', 'Foon Yue', '1952 Citroen-15CV'),
#  ('Tseng', 'Foon Yue', '1969 Chevrolet Camaro Z28'),
#  ('Tseng', 'Foon Yue', '2002 Chevy Corvette'),
#  ('Tseng', 'Foon Yue', '1969 Ford Falcon'),
#  ('Tseng', 'Foon Yue', '1957 Chevy Pickup'),
#  ('Tseng', 'Foon Yue', '1998 Chrysler Plymouth Prowler'),
#  ('Tseng', 'Foon Yue', '1964 Mercedes Tour Bus'),
#  ('Tseng', 'Foon Yue', '1992 Ferrari 360 Spider red'),
#  ('Tseng', 'Foon Yue', '1970 Triumph Spitfire'),
#  ('Tseng', 'Foon Yue', '1970 Dodge Coronet'),
#  ('Tseng', 'Foon Yue', '1958 Chevy Corvette Limited Edition'),
#  ('Tseng', 'Foon Yue', '1992 Porsche Cayenne Turbo Silver'),
#  ('Tseng', 'Foon Yue', '1954 Greyhound Scenicruiser'),
#  ('Tseng', 'Foon Yue', '1937 Lincoln Berline'),
#  ('Tseng', 'Foon Yue', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('Tseng', 'Foon Yue', '1969 Harley Davidson Ultimate Chopper'),
#  ('Tseng', 'Foon Yue', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Tseng', 'Foon Yue', '2002 Suzuki XREO'),
#  ('Tseng', 'Foon Yue', '1957 Vespa GS150'),
#  ('Tseng', 'Foon Yue', '1997 BMW R 1100 S'),
#  ('Tseng', 'Foon Yue', '1982 Ducati 900 Monster'),
#  ('Tseng', 'Foon Yue', '1982 Ducati 996 R'),
#  ('Tseng', 'Foon Yue', '1974 Ducati 350 Mk3 Desmo'),
#  ('Tseng', 'Foon Yue', '2002 Yamaha YZR M1'),
#  ('Tseng', 'Foon Yue', '1969 Corvair Monza'),
#  ('Tseng', 'Foon Yue', '1957 Chevy Pickup'),
#  ('Tseng', 'Foon Yue', '1998 Chrysler Plymouth Prowler'),
#  ('Tseng', 'Foon Yue', '1964 Mercedes Tour Bus'),
#  ('Tseng', 'Foon Yue', '1992 Ferrari 360 Spider red'),
#  ('Tseng', 'Foon Yue', '1970 Triumph Spitfire'),
#  ('Tseng', 'Foon Yue', '1939 Cadillac Limousine'),
#  ('Tseng', 'Foon Yue', '1970 Dodge Coronet'),
#  ('Tseng', 'Foon Yue', '1962 Volkswagen Microbus'),
#  ('Tseng', 'Foon Yue', '1958 Chevy Corvette Limited Edition'),
#  ('Tseng', 'Foon Yue', '1936 Chrysler Airflow'),
#  ('Tseng', 'Foon Yue', '1980’s GM Manhattan Express'),
#  ('Tseng', 'Foon Yue', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Tseng', 'Foon Yue', '1982 Camaro Z28'),
#  ('Tseng', 'Foon Yue', '1993 Mazda RX-7'),
#  ('Tseng', 'Foon Yue', '1995 Honda Civic'),
#  ('Tseng', 'Foon Yue', '1992 Ferrari 360 Spider red'),
#  ('Tseng', 'Foon Yue', '1982 Lamborghini Diablo'),
#  ('Tseng', 'Foon Yue', '1972 Alfa Romeo GTA'),
#  ('Tseng', 'Foon Yue', '1904 Buick Runabout'),
#  ('Tseng', 'Foon Yue', '18th century schooner'),
#  ('Tseng', 'Foon Yue', '1912 Ford Model T Delivery Wagon'),
#  ('Tseng', 'Foon Yue', 'The Schooner Bluenose'),
#  ('Tseng', 'Foon Yue', 'The USS Constitution Ship'),
#  ('Tseng', 'Foon Yue', 'The Titanic'),
#  ('Tseng', 'Foon Yue', 'The Queen Mary'),
#  ('Tseng', 'Foon Yue', 'Pont Yacht'),
#  ('Tseng', 'Foon Yue', '1952 Alpine Renault 1300'),
#  ('Tseng', 'Foon Yue', '1962 LanciaA Delta 16V'),
#  ('Tseng', 'Foon Yue', '1958 Setra Bus'),
#  ('Tseng', 'Foon Yue', '1940 Ford Pickup Truck'),
#  ('Tseng', 'Foon Yue', '1940s Ford truck'),
#  ('Tseng', 'Foon Yue', '1939 Cadillac Limousine'),
#  ('Tseng', 'Foon Yue', '1980’s GM Manhattan Express'),
#  ('Tseng', 'Foon Yue', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Tseng', 'Foon Yue', '1982 Camaro Z28'),
#  ('Tseng', 'Foon Yue', '1957 Chevy Pickup'),
#  ('Tseng', 'Foon Yue', '1998 Chrysler Plymouth Prowler'),
#  ('Tseng', 'Foon Yue', '1970 Dodge Coronet'),
#  ('Tseng', 'Foon Yue', '1992 Porsche Cayenne Turbo Silver'),
#  ('Tseng', 'Foon Yue', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Tseng', 'Foon Yue', '1952 Alpine Renault 1300'),
#  ('Tseng', 'Foon Yue', '1913 Ford Model T Speedster'),
#  ('Tseng', 'Foon Yue', '1934 Ford V8 Coupe'),
#  ('Tseng', 'Foon Yue', '18th Century Vintage Horse Carriage'),
#  ('Tseng', 'Foon Yue', '1917 Maxwell Touring Car'),
#  ('Tseng', 'Foon Yue', '1936 Chrysler Airflow'),
#  ('Tseng', 'Foon Yue', '1972 Alfa Romeo GTA'),
#  ('Tseng', 'Foon Yue', '1970 Triumph Spitfire'),
#  ('Tseng', 'Foon Yue', '1904 Buick Runabout'),
#  ('Tseng', 'Foon Yue', '18th century schooner'),
#  ('Tseng', 'Foon Yue', '1962 City of Detroit Streetcar'),
#  ('Tseng', 'Foon Yue', 'The Mayflower'),
#  ('Tseng', 'Foon Yue', 'The Titanic'),
#  ('Tseng', 'Foon Yue', 'The Queen Mary'),
#  ('Tseng', 'Foon Yue', 'Pont Yacht'),
#  ('Tseng', 'Foon Yue', '2001 Ferrari Enzo'),
#  ('Tseng', 'Foon Yue', '1969 Corvair Monza'),
#  ('Tseng', 'Foon Yue', '1969 Ford Falcon'),
#  ('Tseng', 'Foon Yue', '1903 Ford Model A'),
#  ('Tseng', 'Foon Yue', 'Collectable Wooden Train'),
#  ('Tseng', 'Foon Yue', '1970 Triumph Spitfire'),
#  ('Tseng', 'Foon Yue', '1962 City of Detroit Streetcar'),
#  ('Tseng', 'Foon Yue', 'The Mayflower'),
#  ('Tseng', 'Foon Yue', '1952 Alpine Renault 1300'),
#  ('Tseng', 'Foon Yue', '1962 LanciaA Delta 16V'),
#  ('Tseng', 'Foon Yue', '1958 Setra Bus'),
#  ('Tseng', 'Foon Yue', '1940 Ford Pickup Truck'),
#  ('Tseng', 'Foon Yue', '1940s Ford truck'),
#  ('Tseng', 'Foon Yue', '1939 Cadillac Limousine'),
#  ('Tseng', 'Foon Yue', '1980’s GM Manhattan Express'),
#  ('Tseng', 'Foon Yue', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Tseng', 'Foon Yue', '1982 Camaro Z28'),
#  ('Tseng', 'Foon Yue', '1936 Mercedes Benz 500k Roadster'),
#  ('Tseng', 'Foon Yue', '2002 Suzuki XREO'),
#  ('Tseng', 'Foon Yue', '1969 Dodge Super Bee'),
#  ('Tseng', 'Foon Yue', '1957 Vespa GS150'),
#  ('Tseng', 'Foon Yue', '1957 Corvette Convertible'),
#  ('Tseng', 'Foon Yue', '1982 Ducati 900 Monster'),
#  ('Tseng', 'Foon Yue', '1961 Chevrolet Impala'),
#  ('Tseng', 'Foon Yue', '1982 Ducati 996 R'),
#  ('Tseng', 'Foon Yue', '1974 Ducati 350 Mk3 Desmo'),
#  ('Tseng', 'Foon Yue', '2002 Yamaha YZR M1'),
#  ('Vanauf', 'George', '1969 Harley Davidson Ultimate Chopper'),
#  ('Vanauf', 'George', '1996 Moto Guzzi 1100i'),
#  ('Vanauf', 'George', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Vanauf', 'George', '2002 Suzuki XREO'),
#  ('Vanauf', 'George', '1936 Harley Davidson El Knucklehead'),
#  ('Vanauf', 'George', '1997 BMW R 1100 S'),
#  ('Vanauf', 'George', '1960 BSA Gold Star DBD34'),
#  ('Vanauf', 'George', '1997 BMW F650 ST'),
#  ('Vanauf', 'George', '1972 Alfa Romeo GTA'),
#  ('Vanauf', 'George', '1999 Yamaha Speed Boat'),
#  ('Vanauf', 'George', '1903 Ford Model A'),
#  ('Vanauf', 'George', 'Collectable Wooden Train'),
#  ('Vanauf', 'George', '1904 Buick Runabout'),
#  ('Vanauf', 'George', '18th century schooner'),
#  ('Vanauf', 'George', '1912 Ford Model T Delivery Wagon'),
#  ('Vanauf', 'George', '1940 Ford Delivery Sedan'),
#  ('Vanauf', 'George', 'The Schooner Bluenose'),
#  ('Vanauf', 'George', 'The Mayflower'),
#  ('Vanauf', 'George', 'The USS Constitution Ship'),
#  ('Vanauf', 'George', 'The Titanic'),
#  ('Vanauf', 'George', 'The Queen Mary'),
#  ('Vanauf', 'George', 'Pont Yacht'),
#  ('Vanauf', 'George', '1957 Chevy Pickup'),
#  ('Vanauf', 'George', '1998 Chrysler Plymouth Prowler'),
#  ('Vanauf', 'George', '1964 Mercedes Tour Bus'),
#  ('Vanauf', 'George', '1992 Ferrari 360 Spider red'),
#  ('Vanauf', 'George', '1970 Triumph Spitfire'),
#  ('Vanauf', 'George', '1970 Dodge Coronet'),
#  ('Vanauf', 'George', '1958 Chevy Corvette Limited Edition'),
#  ('Vanauf', 'George', '1992 Porsche Cayenne Turbo Silver'),
#  ('Vanauf', 'George', '1954 Greyhound Scenicruiser'),
#  ('Vanauf', 'George', "1950's Chicago Surface Lines Streetcar"),
#  ('Vanauf', 'George', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Vanauf', 'George', '1962 City of Detroit Streetcar'),
#  ('Vanauf', 'George', '1969 Harley Davidson Ultimate Chopper'),
#  ('Vanauf', 'George', '1996 Moto Guzzi 1100i'),
#  ('Vanauf', 'George', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Vanauf', 'George', '1968 Ford Mustang'),
#  ('Vanauf', 'George', '2002 Suzuki XREO'),
#  ('Vanauf', 'George', '1968 Dodge Charger'),
#  ('Vanauf', 'George', '1970 Plymouth Hemi Cuda'),
#  ('Vanauf', 'George', '1969 Dodge Charger'),
#  ('Vanauf', 'George', '1948 Porsche 356-A Roadster'),
#  ('Vanauf', 'George', '1936 Harley Davidson El Knucklehead'),
#  ('Vanauf', 'George', '1969 Dodge Super Bee'),
#  ('Vanauf', 'George', '1997 BMW R 1100 S'),
#  ('Vanauf', 'George', '1960 BSA Gold Star DBD34'),
#  ('Vanauf', 'George', '1997 BMW F650 ST'),
#  ('Vanauf', 'George', 'Boeing X-32A JSF'),
#  ('Vanauf', 'George', '1965 Aston Martin DB5'),
#  ('Vanauf', 'George', '1999 Indy 500 Monte Carlo SS'),
#  ('Vanauf', 'George', '1948 Porsche Type 356 Roadster'),
#  ('Vanauf', 'George', '1970 Chevy Chevelle SS 454'),
#  ('Vanauf', 'George', '1966 Shelby Cobra 427 S/C'),
#  ('Vanauf', 'George', '1949 Jaguar XK 120'),
#  ('Vanauf', 'George', '1969 Chevrolet Camaro Z28'),
#  ('Vanauf', 'George', '2002 Chevy Corvette'),
#  ('Vanauf', 'George', '1969 Harley Davidson Ultimate Chopper'),
#  ('Vanauf', 'George', '1996 Moto Guzzi 1100i'),
#  ('Vanauf', 'George', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Vanauf', 'George', '2002 Suzuki XREO'),
#  ('Vanauf', 'George', 'P-51-D Mustang'),
#  ('Vanauf', 'George', '1936 Harley Davidson El Knucklehead'),
#  ('Vanauf', 'George', '1997 BMW R 1100 S'),
#  ('Vanauf', 'George', '1960 BSA Gold Star DBD34'),
#  ('Vanauf', 'George', '1900s Vintage Tri-Plane'),
#  ('Vanauf', 'George', '1997 BMW F650 ST'),
#  ('Vanauf', 'George', 'ATA: B757-300'),
#  ('Vanauf', 'George', '2001 Ferrari Enzo'),
#  ('Vanauf', 'George', '1969 Corvair Monza'),
#  ('Vanauf', 'George', '1969 Ford Falcon'),
#  ('Vanauf', 'George', '1970 Triumph Spitfire'),
#  ('Vanauf', 'George', "1950's Chicago Surface Lines Streetcar"),
#  ('Vanauf', 'George', '1962 City of Detroit Streetcar'),
#  ('Vanauf', 'George', '1952 Alpine Renault 1300'),
#  ('Vanauf', 'George', '1958 Setra Bus'),
#  ('Vanauf', 'George', '1940 Ford Pickup Truck'),
#  ('Vanauf', 'George', '1913 Ford Model T Speedster'),
#  ('Vanauf', 'George', '1934 Ford V8 Coupe'),
#  ('Vanauf', 'George', '18th Century Vintage Horse Carriage'),
#  ('Vanauf', 'George', '1917 Maxwell Touring Car'),
#  ('Vanauf', 'George', '1939 Cadillac Limousine'),
#  ('Vanauf', 'George', '1936 Chrysler Airflow'),
#  ('Vanauf', 'George', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Vanauf', 'George', '1982 Camaro Z28'),
#  ('Vanauf', 'George', '1962 LanciaA Delta 16V'),
#  ('Vanauf', 'George', '1958 Setra Bus'),
#  ('Vanauf', 'George', '1964 Mercedes Tour Bus'),
#  ('Vanauf', 'George', '1926 Ford Fire Engine'),
#  ('Vanauf', 'George', '1992 Ferrari 360 Spider red'),
#  ('Vanauf', 'George', '1940s Ford truck'),
#  ('Vanauf', 'George', '1962 Volkswagen Microbus'),
#  ('Vanauf', 'George', '1980’s GM Manhattan Express'),
#  ('Vanauf', 'George', '1954 Greyhound Scenicruiser'),
#  ('Vanauf', 'George', '1996 Peterbilt 379 Stake Bed with Outrigger'),
#  ('Vanauf', 'George', '1982 Camaro Z28'),
#  ('Vanauf', 'George', 'P-51-D Mustang'),
#  ('Vanauf', 'George', '1928 British Royal Navy Airplane'),
#  ('Vanauf', 'George', 'Corsair F4U ( Bird Cage)'),
#  ('Vanauf', 'George', '1900s Vintage Tri-Plane'),
#  ('Vanauf', 'George', '1997 BMW F650 ST'),
#  ('Vanauf', 'George', '1928 Ford Phaeton Deluxe'),
#  ('Vanauf', 'George', '1930 Buick Marquette Phaeton'),
#  ('Vanauf', 'George', 'American Airlines: B767-300'),
#  ('Vanauf', 'George', 'America West Airlines B757-200'),
#  ('Vanauf', 'George', 'ATA: B757-300'),
#  ('Vanauf', 'George', 'F/A 18 Hornet 1/72'),
#  ('Vanauf', 'George', 'American Airlines: MD-11S'),
#  ('Vanauf', 'George', '1972 Alfa Romeo GTA'),
#  ('Vanauf', 'George', '1999 Yamaha Speed Boat'),
#  ('Vanauf', 'George', '1941 Chevrolet Special Deluxe Cabriolet'),
#  ('Vanauf', 'George', '1904 Buick Runabout'),
#  ('Vanauf', 'George', '18th century schooner'),
#  ('Vanauf', 'George', '1912 Ford Model T Delivery Wagon'),
#  ('Vanauf', 'George', '1940 Ford Delivery Sedan'),
#  ('Vanauf', 'George', 'The Schooner Bluenose'),
#  ('Vanauf', 'George', 'HMS Bounty'),
#  ('Vanauf', 'George', 'The USS Constitution Ship'),
#  ('Vanauf', 'George', 'The Titanic'),
#  ('Vanauf', 'George', 'The Queen Mary'),
#  ('Vanauf', 'George', 'Boeing X-32A JSF'),
#  ('Vanauf', 'George', 'Pont Yacht'),
#  ('Vanauf', 'George', '1957 Chevy Pickup'),
#  ('Vanauf', 'George', '1998 Chrysler Plymouth Prowler'),
#  ('Vanauf', 'George', '1964 Mercedes Tour Bus'),
#  ('Vanauf', 'George', '1992 Ferrari 360 Spider red'),
#  ('Vanauf', 'George', '1970 Dodge Coronet'),
#  ('Vanauf', 'George', '1958 Chevy Corvette Limited Edition'),
#  ('Vanauf', 'George', '1992 Porsche Cayenne Turbo Silver'),
#  ('Vanauf', 'George', '1954 Greyhound Scenicruiser'),
#  ('Vanauf', 'George', "1950's Chicago Surface Lines Streetcar"),
#  ('Vanauf', 'George', 'Diamond T620 Semi-Skirted Tanker'),
#  ('Vanauf', 'George', '1996 Moto Guzzi 1100i'),
#  ('Vanauf', 'George', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('Vanauf', 'George', 'P-51-D Mustang'),
#  ('Vanauf', 'George', '1936 Harley Davidson El Knucklehead'),
#  ('Vanauf', 'George', '1928 British Royal Navy Airplane'),
#  ...]

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
